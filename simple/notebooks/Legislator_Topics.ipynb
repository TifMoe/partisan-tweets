# %% [markdown]
# # Text Processing with spaCy

# %%
from pymongo import MongoClient
from configparser import ConfigParser
from collections import Counter
import numpy as np
import pandas as pd
import gzip
import pickle
import warnings
import sys
import os

# text pre-processing
import re
import string
punctuations = string.punctuation
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=DeprecationWarning)
    import spacy
    nlp = spacy.load('en')


# matplotlib
import matplotlib.pyplot as plt
from matplotlib import patches
from mpl_toolkits.mplot3d import Axes3D
% matplotlib inline

# plotly
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, PCA, NMF
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords 
from sklearn.preprocessing import Normalizer, StandardScaler

os.chdir('/Users/tmoeller/ds/twitter-project/partisan-tweets')
import src.data.aws_ec2_functions as aws

# %%
print('Python', sys.version)
print('Pandas', pd.__version__)
print('Numpy', np.__version__)
print('SpaCy', spacy.__version__)
print('Plotly', plotly.__version__)
# Out:
# Python 3.6.3 |Anaconda custom (64-bit)| (default, Oct  6 2017, 12:04:38)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas 0.20.3
# Numpy 1.14.1
# SpaCy 2.0.8
# Plotly 2.4.1

# %%
instance = aws.fetch_instances()[0]

# %% [markdown]
# ## Read in tweet data from Mongodb

# %%
config = ConfigParser()
config.read('config.ini')

client = MongoClient("mongodb://{}:{}@{}/{}".format(
                        config.get('MongoConfig', 'user'),
                        config.get('MongoConfig', 'password'),
                        instance.public_ip_address,
                        config.get('MongoConfig', 'db')
                        ), int(config.get('MongoConfig', 'port')))

# %%
db = client.twitter_db

# %%
db.collection_names()
# Out:
# ['tweets',
#  'favorited_tweets',
#  'train_test_dict',
#  'fav_tweets_dict',
#  'Init',
#  'legislator_tweets_dict']

# %%
db.tweets.count()
# Out:
# 30340

# %% [markdown]
# Let's pull out 20K random tweets from our group of legislators

# %%
# Read in political affiliation by legislator 
with open('data/raw/parties.pickle', 'rb') as file:
    legislator_party = pickle.load(file)

# %%
len(legislator_party)
# Out:
# 524

# %%
relevant_legislators = [sn for sn in legislator_party if legislator_party[sn] != 'Independent']
len(relevant_legislators)
# Out:
# 522

# %% [markdown]
# Because I'm only interested in Republicans and Democrats, let's remove Bernie and that one other Independent party legislator from our group

# %%
cursor = db.tweets.find({})

# %%
tweet_data = [doc for doc in cursor]

# %%
len(tweet_data)
# Out:
# 30340

# %%
tweet_en = [doc for doc in tweet_data if doc['lang']=='en']
len(tweet_en)
# Out:
# 29891

# %%
np.random.seed(42)
tweet_sample = np.random.choice(tweet_en, size=20000, replace=False)

# %%
rawtext = [tweet['full_text'] for tweet in tweet_sample]

rawtext[:5]
# Out:
# ["No father should be charged for this reaction to his daughters' abuse!  https://t.co/AwztDvSP8b",
#  "Constituent input is critical to my work in Congress. On issues like job growth and healthcare, I want to hear your ideas, answer your questions, and talk about our priorities. That's why I'm inviting you to join my next town hall. RSVP here: https://t.co/QiGfM5TKe9 https://t.co/wSav2TVhwu",
#  'Joining @RepLynnJenkins at @DaVita in Topeka. The facility, whose opening has been delayed for years, is finally opening after our legislation to speed up accreditation and improve patient access was signed into law. https://t.co/4NO31mlx0P',
#  '3 out of 4 Pinocchios, Mr. President. Your solar tax is a job killer. #SaveSolarJobs https://t.co/2dLFs1K7mg',
#  "Unborn children can feel pain as early as 20 wks. Only the US &amp; six other nations – China &amp; North Korea among them – allow elective abortions past 20 wks. Tonight, I'll vote for the #Senate to proceed to consideration of the Pain-Capable Unborn Child Protection Act. #TheyFeelPain https://t.co/KKBKbAWGbD"]

# %% [markdown]
# ## Normalize Text

# %% [markdown]
# #### Clean, Tokenize and Vectorize (maybe Stem, Lemmatize)

# %%
def clean_tweet(tweet):
    """
    Function to remove urls, numbers and punctuation, and make lowercase
    """
    no_url = re.sub(r'http\S+', '', tweet)
    clean = re.sub(r'[^\w\s]', '', no_url)
    
    result = ''.join([str(i).replace('\n', ' ').lower() for i in clean if not i.isdigit()])

    return result

# %%
cleantext = [clean_tweet(i) for i in rawtext]
print(rawtext[3], '\n')
print(cleantext[3])
# Out:
# 3 out of 4 Pinocchios, Mr. President. Your solar tax is a job killer. #SaveSolarJobs https://t.co/2dLFs1K7mg
#
#  out of  pinocchios mr president your solar tax is a job killer savesolarjobs

# %%
def spacy_tokenizer(tweet):
    """
    Utility function to remove stopwords, ignore pronouns and tokenize words before vectorizing
    """
    doc = nlp(tweet)
    tokens = [token.orth_ for token in doc if 
              (token.orth_ not in stopwords and token.pos_ in ['NOUN', 'PROPN'])]
            
    return tokens

# %%
print(cleantext[1])

tokens_test = spacy_tokenizer(cleantext[1])
tokens_test
# Out:
# constituent input is critical to my work in congress on issues like job growth and healthcare i want to hear your ideas answer your questions and talk about our priorities thats why im inviting you to join my next town hall rsvp here
# ['constituent',
#  'input',
#  'work',
#  'congress',
#  'issues',
#  'job',
#  'growth',
#  'healthcare',
#  'ideas',
#  'questions',
#  'priorities',
#  'town',
#  'hall',
#  'rsvp']

# %%
#create vectorizer object to generate feature vectors, we will use custom spacy’s tokenizer
vectorizer = TfidfVectorizer(tokenizer = spacy_tokenizer, 
                             ngram_range=(1,1))

# %%
vectorizer.fit(cleantext)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<function spacy_tokenizer at 0x143681b70>, use_idf=True,
#         vocabulary=None)

# %%
dtm = vectorizer.transform(cleantext)

# %%
np.shape(dtm)
# Out:
# (20000, 18074)

# %%
id2word = dict((v, k) for k, v in vectorizer.vocabulary_.items())

# %%
len(id2word)
# Out:
# 18074

# %%
with open('data/processed/legislator_word_features.pkl', 'wb') as wf:
    pickle.dump(id2word, wf)

# %% [markdown]
# # Dimensionality Reduction and Topic Modeling for Small Data

# %% [markdown]
# I've chosen to try LSA and NMF for topic modeling because LDA is best used on large documents

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %% [markdown]
# ## Try LSA

# %%
lsa = TruncatedSVD(n_components=4, random_state=42, algorithm = 'arpack')
dtm_lsa = lsa.fit_transform(dtm)
dtm_lsa = Normalizer(copy=False).fit_transform(dtm_lsa)

# %%
lsa.explained_variance_ratio_
# Out:
# array([0.0027933 , 0.00509778, 0.00466614, 0.00396424])

# %%
print_top_words(lsa, vectorizer.get_feature_names(), 15)
# Out:
# Topic #0:
# amp president people today congress tax americans families trump health country time potus house gun
#
# Topic #1:
# tax cuts taxreform reform jobs workers bonuses americans benefits taxcutsandjobsact employees thanks news paychecks businesses
#
# Topic #2:
# president trump state trumps union potus tonight memo address statement people infrastructure realdonaldtrump russia sotu
#
# Topic #3:
# health care community centers today funding amp budget veterans work day house access center agreement

# %% [markdown]
# ## Try NMF

# %%
nmf = NMF(n_components=10, random_state=42)

dtm_nmf = nmf.fit_transform(dtm)
dtm_nmf = Normalizer(copy=False).fit_transform(dtm_nmf)

# %%
print_top_words(nmf, vectorizer.get_feature_names(), 100)
# Out:
# Topic #0:
# amp infrastructure dreamers immigration security communities americans daca country border realdonaldtrump plan economy america work time budget nation water potus resources law opportunity nations crisis proposal jobs solution week funding issues lives congress leadership housegop programs way women support immigrants enforcement colleagues protectdreamers priorities family efforts act military americas agreement deal fight life spending issue future protections senate job men lets children veterans investment world research process education vote path gop commitment fbi training vets importance progress wall compromise access democrats story trumpbudget environment leaders policy disaster dreamactnow states guest defense energy solutions contributions kids policies safety workforce challenges concerns
#
# Topic #1:
# tax cuts taxreform reform jobs americans workers bonuses benefits taxcutsandjobsact employees news thanks paychecks businesses economy companies goptaxscam wages corporations cut pay month money families law class result taxes business relief company plan growth employee text dollars millions savings years paycheck year investment breaks investments family code credit potus ups job wage taxreformworks crumbs thousands pockets increases deficit trumpbudget worker leave list republicans raise impact gop percent bonus employers results lowes america rates income opportunities programs weeks billions stock week sotu raises increase beginning story act owners exxonmobil ayearoftrump cvs energy billionaires folks individuals works country checkyourcheck infrastructure scam icymi
#
# Topic #2:
# gun violence congress action time students legislation safety parkland school epidemic lives background prevention studentsdemandaction sense enoughisenough act checks schools children laws research nra shootings guns silence americans commonsense republicans weapons neveragain measures endgunviolence communities gunreformnow shooting solutions assault tragedies victims country change tragedy teachers bills members vote ban lobby order steps deaths way inaction courage check america housegop crisis reforms gvro survivors moments week amendment reform year issue moment words responsibility kids cdcgov cdc pain hands parents lets debate leaders member actions mass loophole gunviolence harassment voices power support place illness reminder stonemandouglas rights need nation florida control leadership
#
# Topic #3:
# health care community centers funding budget veterans access americans insurance quality services center agreement crisis communities programs healthcare congress deal work chcs act epidemic program coverage patients year chip priorities resources years leaders providers families millions military disaster longterm trumpbudget womens support child government education relief children leadership emergency fund days senate statement issues week spending conditions administration nations risk redalertchcs treatment medicaid costs seniors family environment minnesotans legislation housing extension country trump troops administrations group safety enrollment months association colleagues efforts thousands premiums areas va decisions chc mtpol opioid need morning addiction proposal aca plan job women twoyear coveredca
#
# Topic #4:
# memo house committee nunes intelligence investigation release republicans statement fbi floor law russia vote security senate government intel democrats public information justice transparency chairman act fisa counsel gop enforcement realdonaldtrump budget week facts nunesmemo legislation doj truth democracy removenunes members attempt support department colleagues committees interference elections night document election effort abuse military releasethememo concerns letter decision muellers process mueller oversight congress campaign agencies rule sanctions speaker memos accountability response attacks officials defense attack memoday americans minority weeks majority trumprussia porter representatives tune devinnunes surveillance houseintelcomm hearing integrity objections fact deal time staff appropriations yesterday icymi efforts clearance page agreement
#
# Topic #5:
# today day thanks office women work time presidents meeting years country service blackhistorymonth men nation history valentines veterans birthday staff year leaders presidentsday life issues week act members hall world students town family washington honor dc remembrance pm senate district county visit rights nations lives conversation community legislation leadership house holocaust support contributions education questions athletes team center month opportunity millions pleasure weremember awareness congratulations states anniversary jews legacy read association city chance harassment group leave military discussion tomorrow hours friend abuse folks efforts floor olympics event morning freedom communities representatives resources constituents hivaids capitol school fight pay tour timesup
#
# Topic #6:
# president trump trumps infrastructure russia birthday administration plan sanctions immigration security congress states proposal democracy elections year america tonight reagan budget dreamers lincoln law investigation election interference leadership promises republicans administrations nations border address obama director policy crisis daca campaign wall years rule attack message promise deficit ronald attacks threat mr americas fact speech actions sotu putin country fbi abraham workers admin efforts vision decision korea words presidentsday russians issue economy nation programs night families russias counsel americans justice immigrants shutdown agenda thingstrumpwonttalkabout investment office mueller thing rhetoric colleagues time credit statement action jobs needs vice ayearoftrump goptaxscam department meddling
#
# Topic #7:
# families prayers train thoughts victims florida school responders colleagues news students accident parkland shooting family heart todays teachers morning tragedy crash stoneman truck scene marjory children community staff law gop ones virginia friends enforcement retreat parents action situation collision hearts life safety lives trumpbudget members act tragedies douglas board schools injuries kids faculty loss doctors leave shootings events passengers condolences incident police goptaxscam child driver workers reports response fmla wife officers home tonight step officials afternoon conference program need county immigration details way moment wv mass communities officer drivers words programs death vehicle class personnel paidleave place line parent recovery
#
# Topic #8:
# people country government america dreamers potus nation world realdonaldtrump disabilities economy way transparency future sotu daca guns lives time children earth step family leadership year millions americans message truth rights work faith thousands congress republicans communities crisis life values democrats opportunity dreams leaders results access number information years protectdreamers promise thing graham hundreds god citizens war rev order jobs policies color laws power trumpbudget job history ada money hands process parties change washington prosperity example interests service friends skills solution things gunreformnow right politics team administration decision honor dream stories deal behalf weapons dreamact love challenges responsibility americas freedom claims
#
# Topic #9:
# state union potus tonight address statement realdonaldtrump sotu tonights tune year pm america presidents trumps guest speech nation night realdonaldtrumps tomorrow country watch reaction stateoftheunion response economy americans challenges et vision whitehouse comments district hall nights opportunity luck live thoughts link town congress washington budget foxbusiness questions accomplishments message chamber agenda morning issues path infrastructure capitol words regulations facebook time foxnews military teamusa home leader icymi history progress joes week isis need department minutes hope strength potuss pyeongchang priorities change women immigrants tennessee unity story values ohio evening interview things hour telephone winter video timesup rep athletes dream dreamer event

# %% [markdown]
# The art is in first decideing what nubmer of topics to select and then in assigning each topic a name, which I'll do below

# %%
topics = ['Immigration',
          'Taxes',
          'Gun Control',
          'Health Care',
          'Memo FBI',
          'Holidays/Honoring',
          'Trump Administration',
          'Thoughts & Prayers',
          'America',
          'SOTU']

# %%
tsne = TSNE(random_state=3211)
tsne_embedding = tsne.fit_transform(dtm_nmf)

# %%
tsne_embedding = pd.DataFrame(tsne_embedding,columns=['x','y'])
tsne_embedding['hue'] = dtm_nmf.argmax(axis=1)

# %%
###code used to create the first plot for getting the colors 
plt.style.use('ggplot')

fig, axs = plt.subplots(1,1, figsize=(12, 12), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .1, wspace=.001)
    
legend_list = []

data = tsne_embedding
scatter = plt.scatter(data=data,x='x',y='y',s=15,c=data['hue'],cmap="Paired")
plt.axis('off')
plt.show()

# Show legend - need to reformat
colors = []
for i in range(len(topics)):
    idx = np.where(data['hue']==i)[0][0]
    color = scatter.get_facecolors()[idx]
    colors.append(color)
    legend_list.append(patches.Ellipse((0, 0), 1, 1, fc=color))
 
plt.legend(legend_list,topics,loc=(0,1),ncol=5, facecolor="white")
plt.axis('off')
plt.show()

# %% [markdown]
# # Plot clusters by political affiliation

# %% [markdown]
# Find how many tweets per user

# %%
from collections import Counter

users_tweets = [tw['user']['screen_name'] for tw in tweet_sample]
print(len(set(users_tweets)), 'Distinct Users')
Counter(users_tweets).most_common(10)
# Out:
# 514 Distinct Users
# [('SenWhitehouse', 213),
#  ('RepRoKhanna', 206),
#  ('RepDonBeyer', 170),
#  ('FrankPallone', 157),
#  ('WhipHoyer', 155),
#  ('senrobportman', 152),
#  ('SenBlumenthal', 149),
#  ('SenTinaSmith', 149),
#  ('RepMaloney', 148),
#  ('RepJayapal', 147)]

# %% [markdown]
# Find how many tweets in each party

# %%
tweet_party = [legislator_party[tw['user']['screen_name'].lower()] for tw in tweet_sample]

# %%
Counter(tweet_party)
# Out:
# Counter({'Democrat': 11702, 'Independent': 107, 'Republican': 8191})

# %% [markdown]
# Let's make the same 2D topic plot we did above but instead of coloring by topic let's color by the assumed political affiliation to see if there are differences in party density between the two classes

# %%
#tsne_embedding['party'] = [(1, 0, 0) if tw=='R' else (0, 0, 1) for tw in tweet_party]
tsne_embedding['party'] = ['red' if tw=='Republican' else 'blue' if tw=='Democrat' else 'green' for tw in tweet_party]

# %%
###code used to create the first plot for getting the colors 
plt.style.use('ggplot')

fig, axs = plt.subplots(1,1, figsize=(12, 12), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .1, wspace=.001)
    
legend_list = []

data = tsne_embedding
scatter = plt.scatter(data=data,x='x',y='y',s=30, alpha=.3, color=data['party'])
plt.axis('off')
plt.show()

# %% [markdown]
# ## Try plotting in 3D

# %%
tsne = TSNE(n_components=3, random_state=3211)
tsne_result = tsne.fit_transform(dtm_nmf)

# %%
tsne_result_scaled = StandardScaler().fit_transform(tsne_result)

tsne_result_scaled_df = pd.DataFrame(tsne_result_scaled,columns=['x','y','z'])
tsne_result_scaled_df['hue'] = dtm_nmf.argmax(axis=1)

# %%
label_to_id_dict = {v:i for i,v in enumerate(list(topics))}
id_to_label_dict = {v: k for k, v in label_to_id_dict.items()}

label_ids = np.array([label_to_id_dict[id_to_label_dict[x]] for x in tsne_result_scaled_df['hue']])

# %%
fig = plt.figure(figsize=(25,25), facecolor='white')
ax = fig.add_subplot(111,projection='3d')
ax.set_facecolor((1,1,1))
ax.xaxis.set_pane_color((1,1,1))
ax.yaxis.set_pane_color((1,1,1))
ax.zaxis.set_pane_color((1,1,1))

plt.grid()
plt.rcParams['grid.color'] = "grey"

nb_classes = len(np.unique(label_ids))
    
for label_id in np.unique(label_ids):
    ax.scatter(tsne_result_scaled[np.where(label_ids == label_id), 0],
                tsne_result_scaled[np.where(label_ids == label_id), 1],
                tsne_result_scaled[np.where(label_ids == label_id), 2],
                alpha=0.3,
                color= plt.cm.Paired(label_id / float(nb_classes)),
                marker='o',
                s=40,
                label=id_to_label_dict[label_id])
    
lgnd = ax.legend(loc='best', prop={'size': 15}, facecolor="white")

for i, t in enumerate(topics):
    lgnd.legendHandles[i]._sizes = [100]

ax.view_init(25, 45)
ax.set_xlim(-2.5, 2.5)
ax.set_ylim(-2.5, 2.5)
ax.set_zlim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %% [markdown]
# ### Try plotting interactive 3D

# %%
# Authenticate account with plotly
plotly.tools.set_credentials_file(username=config.get('Plotly', 'user'), 
                                  api_key=config.get('Plotly', 'api_key'))

# %%
text = [tw for tw in cleantext]
topic = [id_to_label_dict[id_] for id_ in label_ids]
statTooltips = ['<b>{}</b> <br> {}'.format(t, tw) for (t, tw) in zip(topic, text)]

# %%
 data = [go.Scatter3d(
            x = tsne_result_scaled[:,0],
            y = tsne_result_scaled[:,1],
            z = tsne_result_scaled[:,2],
            mode='markers', 
            text=statTooltips,
            hoverinfo='none+none+none+text',
            marker=dict(
                color=plt.cm.Paired(label_ids/ float(nb_classes)),
                size=4,
                opacity=.5,
                line=dict(
                    color=plt.cm.Paired(label_ids/ float(nb_classes)),
                    width=0.5
                ),
            ),
        )]

# %%
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='simple-3d-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tmoeller/12.embed" height="525px" width="100%"></iframe>
